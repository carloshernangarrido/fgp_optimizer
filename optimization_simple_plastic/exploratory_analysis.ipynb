# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
madd = 10
filename = r"C:\Users\joses\Mi unidad\TRABAJO\48_FG_protection\TRABAJO\fgp_optimizer\optimization_simple_plastic\dataset_dense_madd" + \
str(madd) + ".pkl"

with open(filename, 'rb') as f:
    dataset = pickle.load(file=f)

X = np.array(dataset[1])
y = np.array(dataset[2])

# %%
# import pandas as pd


# pd.plotting.scatter_matrix(pd.DataFrame(X), alpha=0.75, figsize=(12, 12), diagonal='hist')

# %%
plt.hist(y)
plt.show()
print(X.shape)
# Out:
# (3240, 6)

# %%
set(X[:, 3])
# Out:
# {0.0, 12600.0, 25200.0, 37800.0, 50400.0, 63000.0}

# %%
i_min = np.argmin(y)
print('min_y', y[i_min])
print('best_X', X[i_min])
print('min_X', np.min(X, axis=0))
print('max_X', np.max(X, axis=0))
# Out:
# min_y 0.008618925975963778
# best_X [0.0e+00 0.0e+00 1.0e+01 6.3e+04 6.3e+04 6.3e+04]
# min_X [0. 0. 0. 0. 0. 0.]
# max_X [1.0e+01 1.0e+01 1.0e+01 6.3e+04 6.3e+04 6.3e+04]
