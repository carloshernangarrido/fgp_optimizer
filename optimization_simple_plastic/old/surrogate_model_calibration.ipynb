# %%
import numpy as np
import tensorflow as tf

import os

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %% [markdown]
# # Load data from full simulations

# %%
def load_multiple_records(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    records = []
    current_record = []
    header = lines[0].strip()  # Assuming the first line is the header
    
    for line in lines:
        if line.strip() == header:
            if current_record:
                records.append(np.array(current_record, dtype=float))
                current_record = []
        else:
            current_record.append([float(value) for value in line.split()])
    
    if current_record:  # Add the last record if the file doesn't end with a header line
        records.append(np.array(current_record, dtype=float))
    
    return records

# %%
# Folder path where the files are stored
folder_path = r'C:\Users\joses\Mi unidad\TRABAJO\48_FG_protection\TRABAJO\fgp_optimizer\optimization_simple_plastic\full_simulation_data\iter0'
# folder_path = r'C:\Users\joses\Mi unidad\TRABAJO\48_FG_protection\TRABAJO\fgp_optimizer\optimization_simple_plastic\full_simulation_data\iter0_1nodo'

# Dictionary to store the data for each node
data_dicts = {}
node_ids = []
nodes = np.loadtxt(os.path.join(folder_path, 'nodos.txt'))[:, 1:]

# Iterate over each file in the folder
for filename in os.listdir(folder_path):
    if filename.startswith('presion_node'):
        # Extract the node ID from the filename
        node_id = filename.split(' ')[-1]
        node_ids.append(node_id)
        
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        
        # Load the data, skipping the first line
        data = load_multiple_records(file_path)
        
        # Store the time and pressure data in the dictionary under the node_id
        data_dicts[node_id] = {
            'time': data[0][:, 0],
            'pressure': -np.mean(np.array(data), axis=0)[:,1],
            'displacement': np.loadtxt(file_path.replace('presion_node ', 'flecha_node'), skiprows=1)[:, 1], 
            'coordinates': nodes[int(node_id)]
        }

# %%
fig, ax = plt.subplots(2, 1, sharex='col')
ax = ax.flatten()

n_rows = 600
for node_id in node_ids:
    ax[0].plot(data_dicts[node_id]['time'][:n_rows], data_dicts[node_id]['pressure'][:n_rows])
    ax[1].plot(data_dicts[node_id]['time'][:n_rows], data_dicts[node_id]['displacement'][:n_rows])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
coordinates = np.array([data_dicts[node_id]['coordinates'] for node_id in node_ids])

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(coordinates[:, 0], coordinates[:, 1], coordinates[:, 2])

# Set labels (optional)
ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')
ax.set_zlabel('Z Coordinate')

plt.show()
# Out:
# C:\Users\joses\AppData\Local\Temp\ipykernel_15000\2296854808.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
stride = 10

# Assuming data_dicts and node_ids are already defined
coordinates = np.array([data_dicts[node_id]['coordinates'] for node_id in node_ids])
displacement_data = np.array([data_dicts[node_id]['displacement'][:n_rows] for node_id in node_ids])
pressure_data = np.array([data_dicts[node_id]['pressure'][:n_rows] for node_id in node_ids])
time_data = np.array(data_dicts[node_ids[0]]['time'][:n_rows])

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Initialize scatter plot
scat = ax.scatter(coordinates[:, 0], coordinates[:, 1], coordinates[:, 2])

# Set labels (optional)
ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')
ax.set_zlabel('Z Coordinate')

# Function to update the scatter plot
def update(frame):
    ax.clear()
    ax.set_xlabel('X Coordinate')
    ax.set_ylabel('Y Coordinate')
    ax.set_zlabel('Z Coordinate')
    ax.set_xlim([coordinates[:, 0].min(), coordinates[:, 0].max()])
    ax.set_ylim([coordinates[:, 1].min(), coordinates[:, 1].max()])
    ax.set_zlim([displacement_data.min(), displacement_data.max()])
    ax.scatter(coordinates[:, 0], coordinates[:, 1], displacement_data[:, frame], c=pressure_data[:, frame], cmap='hot')
    return scat,

# Create the animation
ani = FuncAnimation(fig, update, frames=range(0, len(displacement_data[0]), stride), interval=1000/25, blit=False)

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc83b670caf72415abeecb83f0aaddf89">
#   <div class="anim-controls">
#     <input id="_anim_sliderc83b670caf72415abeecb83f0aaddf89" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc83b670caf72415abeecb83f0aaddf89.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animc83b670caf72415abeecb83f0aaddf89.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animc83b670caf72415abeecb83f0aaddf89.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animc83b670caf72415abeecb83f0aaddf89.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animc83b670caf72415abeecb83f0aaddf89.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animc83b670caf72415abeecb83f0aaddf89.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animc83b670caf72415abeecb83f0aaddf89.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animc83b670caf72415abeecb83f0aaddf89.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animc83b670caf72415abeecb83f0aaddf89.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animc83b670caf72415abeecb83f0aaddf89.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectc83b670caf72415abeecb83f0aaddf89"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c83b670caf72415abeecb83f0aaddf89"
#              >
#       <label for="_anim_radio1_c83b670caf72415abeecb83f0aaddf89">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c83b670caf72415abeecb83f0aaddf89"
#              checked>
#       <label for="_anim_radio2_c83b670caf72415abeecb83f0aaddf89">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c83b670caf72415abeecb83f0aaddf89"
#              >
#       <label for="_anim_radio3_c83b670caf72415abeecb83f0aaddf89">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc83b670caf72415abeecb83f0aaddf89";
#     var slider_id = "_anim_sliderc83b670caf72415abeecb83f0aaddf89";
#     var loop_select_id = "_anim_loop_selectc83b670caf72415abeecb83f0aaddf89";
#     var frames = new Array(60);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjcuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8pXeV/AAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAEAAElEQ
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(f'{time_data.shape=}')
# Out:
# time_data.shape=(600,)

# %%
print(f'{displacement_data.shape=}')
# Out:
# displacement_data.shape=(40, 600)

# %%
print(f'{pressure_data.shape=}')
# Out:
# pressure_data.shape=(40, 600)

# %% [markdown]
# # Definition of the surrogate model

# %%
class SDOFDynamicsLayer(tf.keras.layers.Layer):
  def __init__(self, delta_t, n):
    super(SDOFDynamicsLayer, self).__init__()
    self.delta_t = delta_t
    self.n = n
  
    # Trainable parameters: ms, ks, cs
    self._ms = tf.Variable(1.0, dtype=tf.float32, trainable=True, name="raw_mass")
    self._ks = tf.Variable(1.0, dtype=tf.float32, trainable=True, name="raw_stiffness")
    self._cs = tf.Variable(0.1, dtype=tf.float32, trainable=True, name="raw_damping")

  @property
  def ms(self):
    return self._ms ** 2
    # return tf.nn.softplus(self._ms)  # Ensure positive mass

  @property
  def ks(self):
    return self._ks ** 2
    # return tf.nn.softplus(self._ks)  # Ensure positive stiffness

  @property
  def cs(self):
    return self._cs ** 2
    # return tf.nn.softplus(self._cs)  # Ensure positive damping

  def call(self, inputs):
    state_k, f_k = inputs  # Unpack the input tensor

    # Define matrices A and B for the discrete-time system
    A_d = tf.stack([[1.0, self.delta_t],
                    [-(self.ks / self.ms) * self.delta_t, 1.0 - (self.cs / self.ms) * self.delta_t]], axis=0)

    B_d = tf.stack([[0.0], 
                    [self.delta_t / self.ms]], axis=0)

    # Expand dims of A_d and B_d to match the batch size (broadcasting to batch size)
    A_d = tf.expand_dims(A_d, axis=0)  
    B_d = tf.expand_dims(B_d, axis=0) 
    
    # Compute next state at time k+1
    state_k_plus_1_dyn = tf.matmul(A_d, state_k)  # A_d [batch_size, 2, 2], state_k [batch_size, 2, 1]
    state_k_plus_1_ind = tf.matmul(B_d, f_k)  # B_d [batch_size, 2, 1], f_k [batch_size, 1]
    state_k_plus_1 = state_k_plus_1_dyn + state_k_plus_1_ind

    # Remove extra dimension for easier slicing
    state_k_plus_1 = tf.squeeze(state_k_plus_1, axis=-1)  # Shape [batch_size, 2]
    
    return state_k_plus_1


# # Custom constraint to ensure the largest absolute value of the weights is 1
# class MaxAbsConstraint(tf.keras.constraints.Constraint):
#     def __call__(self, weights):
#         max_abs_value = tf.reduce_max(tf.abs(weights))
#         return weights / max_abs_value

# Custom constraint to ensure the largest absolute value of the weights is 1
class MaxAbsConstraint(tf.keras.constraints.Constraint):
    def __call__(self, weights):
        return weights  
    
# Custom call back for sharing weights
class WeightSharingCallback(tf.keras.callbacks.Callback):
    def on_batch_end(self, batch, logs=None):
        scalar2vector_weights = self.model.get_layer('scalar2vector_x').get_weights()[0]
        vector2scalar_weights = self.model.get_layer('vector2scalar_x').get_weights()[0]
        transposed_scalar2vector_weights = tf.transpose(scalar2vector_weights)
        
        # Ensure the weights are symmetric
        symmetric_weights = (vector2scalar_weights + transposed_scalar2vector_weights) / 2
        
        # Normalize the symmetric weights to ensure the dot product is 1
        norm = tf.norm(symmetric_weights)
        normalized_weights = symmetric_weights / norm
        
        self.model.get_layer('vector2scalar_x').set_weights([normalized_weights])
        self.model.get_layer('scalar2vector_x').set_weights([tf.transpose(normalized_weights)])


def create_sdof_model(delta_t, n, linear_projection: bool = True, 
                      vector2scalar_f_const: bool = True, 
                      vector2scalar_x_const: bool = False, 
                      scalar2vector_x_const: bool = False):
    # Define the input layers
    xr_input = tf.keras.Input(shape=(n,), name='xr_input')  # Displacement input
    xrdot_input = tf.keras.Input(shape=(n,), name='xrdot_input')  # Velocity input
    fr_input = tf.keras.Input(shape=(n,), name='fr_input')  # Force input

    # Linear projection layers
    if linear_projection:
        if vector2scalar_f_const:
            vector2scalar_f = tf.keras.layers.Dense(1, activation='linear', use_bias=False, 
                                                    kernel_constraint=MaxAbsConstraint(), kernel_initializer='ones',
                                                    name='vector2scalar_f', trainable=False)
        else:
            vector2scalar_f = tf.keras.layers.Dense(1, activation='linear', use_bias=False, 
                                                    kernel_constraint=MaxAbsConstraint(), kernel_initializer='ones',
                                                    name='vector2scalar_f', trainable=True)
        if vector2scalar_x_const:
            vector2scalar_x = tf.keras.layers.Dense(1, activation='linear', use_bias=False, 
                                                    kernel_constraint=MaxAbsConstraint(), kernel_initializer='ones',
                                                    name='vector2scalar_x', trainable=False)
        else:
            vector2scalar_x = tf.keras.layers.Dense(1, activation='linear', use_bias=False, 
                                                    kernel_constraint=MaxAbsConstraint(), kernel_initializer='ones',
                                                    name='vector2scalar_x', trainable=True)
        if scalar2vector_x_const:
           scalar2vector_x = tf.keras.layers.Dense(n, activation='linear', use_bias=False, 
                                                   kernel_constraint=MaxAbsConstraint(), kernel_initializer='ones',
                                                   name='scalar2vector_x', trainable=False)
        else:
           scalar2vector_x = tf.keras.layers.Dense(n, activation='linear', use_bias=False, 
                                                   kernel_constraint=MaxAbsConstraint(), kernel_initializer='ones',
                                                   name='scalar2vector_x', trainable=True)
    else:
        raise NotImplementedError("Non-linear projection is not implemented.")

    # Transform vectors into scalars
    x_k = vector2scalar_x(xr_input)  

    xdot_k = vector2scalar_x(xrdot_input)

    # Add an extra dimension to match the required input shape
    x_k = tf.expand_dims(x_k, axis=-1)  # Shape [batch_size, 1, 1]
    xdot_k = tf.expand_dims(xdot_k, axis=-1)  # Shape [batch_size, 1, 1]

    state_k = tf.concat([x_k, xdot_k], axis=1)  # Shape [batch_size, 2, 1]

    # Process force input similarly
    f_k = vector2scalar_f(fr_input)
    f_k = tf.expand_dims(f_k, axis=-1)  # Shape [batch_size, 1]

    # Create SDOF dynamics layer
    dynamics_layer = SDOFDynamicsLayer(delta_t, n)
    state_k_plus_1 = dynamics_layer((state_k, f_k))

    # Extract new state variables
    x_k_plus_1 = state_k_plus_1[:, 0]  # Shape [batch_size]
    xdot_k_plus_1 = state_k_plus_1[:, 1]  # Shape [batch_size]

    # Ensure that x_k_plus_1 and xdot_k_plus_1 have at least two dimensions
    x_k_plus_1 = tf.expand_dims(x_k_plus_1, axis=-1)  # Shape [batch_size, 1]
    xdot_k_plus_1 = tf.expand_dims(xdot_k_plus_1, axis=-1)  # Shape [batch_size, 1]

    # Transform scalars back into vectors
    xr_k_plus_1 = scalar2vector_x(x_k_plus_1)
    xrdot_k_plus_1 = scalar2vector_x(xdot_k_plus_1)

    # Create a model
    model = tf.keras.Model(inputs=[xr_input, xrdot_input, fr_input], outputs=[xr_k_plus_1, xrdot_k_plus_1])

    return model

# %%
# Example usage
delta_t = np.round(np.mean(np.diff(time_data)), 5)
n = displacement_data.shape[0]  # Example dimension
sdof_model = create_sdof_model(delta_t, n)
sdof_model.summary()  # Print the model summary
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  xr_input (InputLayer)       [(None, 40)]                 0         []
#
#  xrdot_input (InputLayer)    [(None, 40)]                 0         []
#
#  vector2scalar_x (Dense)     (None, 1)                    40        ['xr_input[0][0]',
#                                                                      'xrdot_input[0][0]']
#
#  fr_input (InputLayer)       [(None, 40)]                 0         []
#
#  tf.expand_dims_45 (TFOpLam  (None, 1, 1)                 0         ['vector2scalar_x[0][0]']
#  bda)
#
#  tf.expand_dims_46 (TFOpLam  (None, 1, 1)                 0         ['vector2scalar_x[1][0]']
#  bda)
#
#  vector2scalar_f (Dense)     (None, 1)                    40        ['fr_input[0][0]']
#
#  tf.concat_9 (TFOpLambda)    (None, 2, 1)                 0         ['tf.expand_dims_45[0][0]',
#                                                                      'tf.expand_dims_46[0][0]']
#
#  tf.expand_dims_47 (TFOpLam  (None, 1, 1)                 0         ['vector2scalar_f[0][0]']
#  bda)
#
#  sdof_dynamics_layer_9 (SDO  (None, 2)                    3         ['tf.concat_9[0][0]',
#  FDynamicsLayer)                                                     'tf.expand_dims_47[0][0]']
#
#  tf.__operators__.getitem_1  (None,)                      0         ['sdof_dynamics_layer_9[0][0]'
#  8 (SlicingOpLambda)                                                ]
#
#  tf.__operators__.getitem_1  (None,)                      0         ['sdof_dynamics_layer_9[0][0]'
#  9 (SlicingOpLambda)                                                ]
#
#  tf.expand_dims_48 (TFOpLam  (None, 1)                    0         ['tf.__operators__.getitem_18[
#  bda)                                                               0][0]']
#
#  tf.expand_dims_49 (TFOpLam  (None, 1)                    0         ['tf.__operators__.getitem_19[
#  bda)                                                               0][0]']
#
#  scalar2vector_x (Dense)     (None, 40)                   40        ['tf.expand_dims_48[0][0]',
#                                                                      'tf.expand_dims_49[0][0]']
#
# ==================================================================================================
# Total params: 123 (492.00 Byte)
# Trainable params: 83 (332.00 Byte)
# Non-trainable params: 40 (160.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Train set generation from time history dataset

# %% [markdown]
# ## Resampling to a constant delta_t

# %%
from scipy.interpolate import interp1d


# New time vector
time_resampled = np.arange(time_data[0], time_data[-1], delta_t)

# Create an interpolation function
interp_disp_func = interp1d(time_data, displacement_data, kind='linear', fill_value="extrapolate")
interp_pres_func = interp1d(time_data, pressure_data, kind='linear', fill_value="extrapolate")


# Resample values using the interpolation function
displacement_resampled = interp_disp_func(time_resampled)
pressure_resampled = interp_pres_func(time_resampled)

print(f'{time_resampled.shape=}')
# Out:
# time_resampled.shape=(599,)

# %% [markdown]
# ## Velocity estimation

# %%
velocity_resampled = np.diff(displacement_resampled, prepend=0)/delta_t

# %% [markdown]
# ### Plots for inspecting resampling

# %%
fig, ax = plt.subplots(3, 1, sharex='col')
ax = ax.flatten()


for node_id in node_ids:
    ax[0].plot(time_resampled, displacement_resampled.T)
    ax[1].plot(time_resampled, velocity_resampled.T)
    ax[2].plot(time_resampled, pressure_resampled.T)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## X and Y

# %%
X1 = displacement_resampled.T[:-1, :]
X2 = velocity_resampled.T[:-1, :]
X3 = pressure_resampled.T[:-1, :]

Y1 = displacement_resampled.T[1:, :]
Y2 = velocity_resampled.T[1:, :]

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import MinMaxScaler


scale_X1 = np.max(np.abs(X1))
scale_X2 = np.max(np.abs(X2))
scale_X3 = np.max(np.abs(X3))
scale_Y1 = np.max(np.abs(Y1))
scale_Y2 = np.max(np.abs(Y2))

X1_norm = X1 / scale_X1
X2_norm = X2 / scale_X2
X3_norm = X3 / scale_X3
Y1_norm = Y1 / scale_Y1
Y2_norm = Y2 / scale_Y2

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split


# Split the datasets into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(
    np.hstack([X1_norm, X2_norm, X3_norm]),  # Combine inputs into a single array and transpose
    np.hstack([Y1_norm, Y2_norm]),  # Combine outputs into a single array and transpose
    test_size=0.1,  # % of the data will be used for testing
    random_state=42,  # Optional: set a seed for reproducibility
    shuffle=True
)

# Now we have training and testing datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# X_train shape: (538, 120)
# X_test shape: (60, 120)
# Y_train shape: (538, 80)
# Y_test shape: (60, 80)

# %% [markdown]
# # Compile and Fit the model

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=2)

callbacks=[WeightSharingCallback(), reduce_lr]
# callbacks=[reduce_lr]

delta_t_model = 1.0
sdof_model = create_sdof_model(delta_t_model, n)

sdof_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.1), loss='mean_squared_error', loss_weights=[1.0, 0.1])

# epochs
epochs = 50
batch_size = 128

# Fit the model and capture the history
history = sdof_model.fit([X_train[:, :n], X_train[:, n:2*n], X_train[:, 2*n:]], [Y_train[:, :n], Y_train[:, n:2*n]], 
               validation_data=[[X_test[:, :n], X_test[:, n:2*n], X_test[:, 2*n:]], [Y_test[:, :n], Y_test[:, n:2*n]]],
               batch_size=batch_size, epochs=epochs, callbacks=callbacks)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 2s 140ms/step - loss: 98.3139 - scalar2vector_x_loss: 94.7379 - scalar2vector_x_1_loss: 35.7596 - val_loss: 0.1904 - val_scalar2vector_x_loss: 0.1769 - val_scalar2vector_x_1_loss: 0.1343 - lr: 0.1000
# Epoch 2/50
# 1/5 [=====>........................] - ETA: 0s - loss: 0.2232 - scalar2vector_x_loss: 0.2113 - scalar2vector_x_1_loss: 0.1189WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0037s vs `on_train_batch_end` time: 0.0076s). Check your callbacks.
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2096 - scalar2vector_x_loss: 0.1987 - scalar2vector_x_1_loss: 0.1095 - val_loss: 0.1742 - val_scalar2vector_x_loss: 0.1629 - val_scalar2vector_x_1_loss: 0.1130 - lr: 0.1000
# Epoch 3/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1822 - scalar2vector_x_loss: 0.1738 - scalar2vector_x_1_loss: 0.0847 - val_loss: 0.1586 - val_scalar2vector_x_loss: 0.1498 - val_scalar2vector_x_1_loss: 0.0879 - lr: 0.1000
# Epoch 4/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1619 - scalar2vector_x_loss: 0.1552 - scalar2vector_x_1_loss: 0.0672 - val_loss: 0.1506 - val_scalar2vector_x_loss: 0.1432 - val_scalar2vector_x_1_loss: 0.0742 - lr: 0.1000
# Epoch 5/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1509 - scalar2vector_x_loss: 0.1451 - scalar2vector_x_1_loss: 0.0576 - val_loss: 0.1461 - val_scalar2vector_x_loss: 0.1395 - val_scalar2vector_x_1_loss: 0.0662 - lr: 0.1000
# Epoch 6/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1445 - scalar2vector_x_loss: 0.1393 - scalar2vector_x_1_loss: 0.0518 - val_loss: 0.1432 - val_scalar2vector_x_loss: 0.1371 - val_scalar2vector_x_1_loss: 0.0608 - lr: 0.1000
# Epoch 7/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1398 - scalar2vector_x_loss: 0.1350 - scalar2vector_x_1_loss: 0.0478 - val_loss: 0.1408 - val_scalar2vector_x_loss: 0.1352 - val_scalar2vector_x_1_loss: 0.0565 - lr: 0.1000
# Epoch 8/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1361 - scalar2vector_x_loss: 0.1316 - scalar2vector_x_1_loss: 0.0445 - val_loss: 0.1388 - val_scalar2vector_x_loss: 0.1335 - val_scalar2vector_x_1_loss: 0.0527 - lr: 0.1000
# Epoch 9/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1327 - scalar2vector_x_loss: 0.1285 - scalar2vector_x_1_loss: 0.0416 - val_loss: 0.1369 - val_scalar2vector_x_loss: 0.1320 - val_scalar2vector_x_1_loss: 0.0492 - lr: 0.1000
# Epoch 10/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1295 - scalar2vector_x_loss: 0.1256 - scalar2vector_x_1_loss: 0.0389 - val_loss: 0.1351 - val_scalar2vector_x_loss: 0.1305 - val_scalar2vector_x_1_loss: 0.0458 - lr: 0.1000
# Epoch 11/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1262 - scalar2vector_x_loss: 0.1226 - scalar2vector_x_1_loss: 0.0362 - val_loss: 0.1332 - val_scalar2vector_x_loss: 0.1290 - val_scalar2vector_x_1_loss: 0.0423 - lr: 0.1000
# Epoch 12/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.1232 - scalar2vector_x_loss: 0.1199 - scalar2vector_x_1_loss: 0.0335 - val_loss: 0.1315 - val_scalar2vector_x_loss: 0.1276 - val_scalar2vector_x_1_loss: 0.0390 - lr: 0.1000
# Epoch 13/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1201 - scalar2vector_x_loss: 0.1170 - scalar2vector_x_1_loss: 0.0310 - val_loss: 0.1298 - val_scalar2vector_x_loss: 0.1263 - val_scalar2vector_x_1_loss: 0.0357 - lr: 0.1000
# Epoch 14/50
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1172 - scalar2vector_x_loss: 0.1143 - scalar2vector_x_1_loss: 0.0285 - val_loss: 0.1283 - val_scalar2vector_x_loss: 0.1250 - val_scalar2vector_x_1_loss: 0.0325 - lr: 0.1000
# Epoch 15/50
# 5/5 [==============================] - 0s 54ms/step - loss: 0.1144 - scalar2vector_x_loss: 0.1118 - scalar2vector_x_1_loss: 0.0262 - val_loss: 0.1268 - val_scalar2vector_x_loss: 0.1239 - val_scalar2vector_x_1_loss: 0.0296 - lr: 0.1000
# Epoch 16/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1119 - scalar2vector_x_loss: 0.1095 - scalar2vector_x_1_loss: 0.0240 - val_loss: 0.1256 - val_scalar2vector_x_loss: 0.1229 - val_scalar2vector_x_1_loss: 0.0269 - lr: 0.1000
# Epoch 17/50
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1097 - scalar2vector_x_loss: 0.1075 - scalar2vector_x_1_loss: 0.0221 - val_loss: 0.1245 - val_scalar2vector_x_loss: 0.1221 - val_scalar2vector_x_1_loss: 0.0245 - lr: 0.1000
# Epoch 18/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1078 - scalar2vector_x_loss: 0.1058 - scalar2vector_x_1_loss: 0.0205 - val_loss: 0.1236 - val_scalar2vector_x_loss: 0.1214 - val_scalar2vector_x_1_loss: 0.0224 - lr: 0.1000
# Epoch 19/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.1062 - scalar2vector_x_loss: 0.1043 - scalar2vector_x_1_loss: 0.0190 - val_loss: 0.1229 - val_scalar2vector_x_loss: 0.1209 - val_scalar2vector_x_1_loss: 0.0206 - lr: 0.1000
# Epoch 20/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0179 - val_loss: 0.1225 - val_scalar2vector_x_loss: 0.1205 - val_scalar2vector_x_1_loss: 0.0192 - lr: 0.1000
# Epoch 21/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1040 - scalar2vector_x_loss: 0.1023 - scalar2vector_x_1_loss: 0.0171 - val_loss: 0.1223 - val_scalar2vector_x_loss: 0.1204 - val_scalar2vector_x_1_loss: 0.0181 - lr: 0.1000
# Epoch 22/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.1034 - scalar2vector_x_loss: 0.1018 - scalar2vector_x_1_loss: 0.0167 - val_loss: 0.1223 - val_scalar2vector_x_loss: 0.1205 - val_scalar2vector_x_1_loss: 0.0175 - lr: 0.1000
# Epoch 23/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1033 - scalar2vector_x_loss: 0.1016 - scalar2vector_x_1_loss: 0.0165 - val_loss: 0.1225 - val_scalar2vector_x_loss: 0.1208 - val_scalar2vector_x_1_loss: 0.0173 - lr: 0.1000
# Epoch 24/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1034 - scalar2vector_x_loss: 0.1018 - scalar2vector_x_1_loss: 0.0166 - val_loss: 0.1228 - val_scalar2vector_x_loss: 0.1210 - val_scalar2vector_x_1_loss: 0.0173 - lr: 0.0500
# Epoch 25/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1038 - scalar2vector_x_loss: 0.1021 - scalar2vector_x_1_loss: 0.0168 - val_loss: 0.1231 - val_scalar2vector_x_loss: 0.1214 - val_scalar2vector_x_1_loss: 0.0176 - lr: 0.0500
# Epoch 26/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1041 - scalar2vector_x_loss: 0.1024 - scalar2vector_x_1_loss: 0.0171 - val_loss: 0.1233 - val_scalar2vector_x_loss: 0.1215 - val_scalar2vector_x_1_loss: 0.0177 - lr: 0.0250
# Epoch 27/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1043 - scalar2vector_x_loss: 0.1026 - scalar2vector_x_1_loss: 0.0173 - val_loss: 0.1235 - val_scalar2vector_x_loss: 0.1217 - val_scalar2vector_x_1_loss: 0.0178 - lr: 0.0250
# Epoch 28/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1045 - scalar2vector_x_loss: 0.1027 - scalar2vector_x_1_loss: 0.0174 - val_loss: 0.1235 - val_scalar2vector_x_loss: 0.1217 - val_scalar2vector_x_1_loss: 0.0179 - lr: 0.0125
# Epoch 29/50
# 5/5 [==============================] - 0s 47ms/step - loss: 0.1046 - scalar2vector_x_loss: 0.1028 - scalar2vector_x_1_loss: 0.0175 - val_loss: 0.1236 - val_scalar2vector_x_loss: 0.1218 - val_scalar2vector_x_1_loss: 0.0180 - lr: 0.0125
# Epoch 30/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1047 - scalar2vector_x_loss: 0.1029 - scalar2vector_x_1_loss: 0.0175 - val_loss: 0.1237 - val_scalar2vector_x_loss: 0.1219 - val_scalar2vector_x_1_loss: 0.0180 - lr: 0.0063
# Epoch 31/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1047 - scalar2vector_x_loss: 0.1030 - scalar2vector_x_1_loss: 0.0176 - val_loss: 0.1237 - val_scalar2vector_x_loss: 0.1219 - val_scalar2vector_x_1_loss: 0.0180 - lr: 0.0063
# Epoch 32/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1048 - scalar2vector_x_loss: 0.1030 - scalar2vector_x_1_loss: 0.0176 - val_loss: 0.1237 - val_scalar2vector_x_loss: 0.1219 - val_scalar2vector_x_1_loss: 0.0181 - lr: 0.0031
# Epoch 33/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1048 - scalar2vector_x_loss: 0.1030 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 0.0031
# Epoch 34/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1048 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 0.0016
# Epoch 35/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 0.0016
# Epoch 36/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 7.8125e-04
# Epoch 37/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 7.8125e-04
# Epoch 38/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 3.9063e-04
# Epoch 39/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 3.9063e-04
# Epoch 40/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 1.9531e-04
# Epoch 41/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 1.9531e-04
# Epoch 42/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 9.7656e-05
# Epoch 43/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 9.7656e-05
# Epoch 44/50
# 5/5 [==============================] - 0s 35ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 4.8828e-05
# Epoch 45/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 4.8828e-05
# Epoch 46/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 2.4414e-05
# Epoch 47/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 2.4414e-05
# Epoch 48/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 1.2207e-05
# Epoch 49/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 1.2207e-05
# Epoch 50/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.1049 - scalar2vector_x_loss: 0.1031 - scalar2vector_x_1_loss: 0.0177 - val_loss: 0.1238 - val_scalar2vector_x_loss: 0.1220 - val_scalar2vector_x_1_loss: 0.0181 - lr: 6.1035e-06

# %%
# Plotting the loss
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
phi_f = sdof_model.get_layer('vector2scalar_f').weights[0].numpy().T
phi_x = sdof_model.get_layer('vector2scalar_x').weights[0].numpy().T
phi_x_T = sdof_model.get_layer('scalar2vector_x').weights[0].numpy().T

coordinates = np.array([data_dicts[node_id]['coordinates'] for node_id in node_ids])

# Make sure interactive plotting is enabled
# %matplotlib widget


# Create a 3D scatter plot
fig_phi_x = plt.figure()
ax_phi_x = fig_phi_x.add_subplot(111, projection='3d')
ax_phi_x.scatter(coordinates[:, 0], coordinates[:, 1], phi_x.flatten())
ax_phi_x.set_zlim([-1,1])
# Set labels (optional)
ax_phi_x.set_xlabel('X Coordinate')
ax_phi_x.set_ylabel('Y Coordinate')
ax_phi_x.set_zlabel('Z Coordinate')
plt.show()


# Create a 3D scatter plot
fig_phi_x = plt.figure()
ax_phi_x = fig_phi_x.add_subplot(111, projection='3d')
ax_phi_x.scatter(coordinates[:, 0], coordinates[:, 1], phi_f.flatten())
ax_phi_x.set_zlim([-1,1])
# Set labels (optional)
ax_phi_x.set_xlabel('X Coordinate')
ax_phi_x.set_ylabel('Y Coordinate')
ax_phi_x.set_zlabel('Z Coordinate')
plt.show()

# Create a 3D scatter plot
fig_phi_x = plt.figure()
ax_phi_x = fig_phi_x.add_subplot(111, projection='3d')
ax_phi_x.scatter(coordinates[:, 0], coordinates[:, 1], phi_x_T.flatten())
ax_phi_x.set_zlim([-1,1])
# Set labels (optional)
ax_phi_x.set_xlabel('X Coordinate')
ax_phi_x.set_ylabel('Y Coordinate')
ax_phi_x.set_zlabel('Z Coordinate')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Predictions as an auto-regressive model

# %%
X1_norm_pred = 0*X1_norm
X2_norm_pred = 0*X2_norm

for i in range(X3_norm.shape[0]-1):
    X1_norm_pred[i+1, :], X2_norm_pred[i+1, :] = sdof_model.predict([X1_norm_pred[i, :].reshape((1,-1)), X2_norm_pred[i, :].reshape((1,-1)), X3_norm[i, :].reshape((1,-1))])
# Out:
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step

# %%
fig, ax = plt.subplots(2, 2, sharex='all')


for node_id in node_ids:
    ax[0,0].plot(X1_norm)
    ax[1,0].plot(X2_norm)
    ax[0,1].plot(X1_norm_pred)
    ax[1,1].plot(X2_norm_pred)
    ax[0,1].set_ylim([-1, 0])
    ax[1,1].set_ylim([-1, 0])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(2, 2, sharex='col')


for node_id in node_ids:
    ax[0,0].plot(X1_norm*scale_X1)
    ax[1,0].plot(X2_norm*scale_X2)
    ax[0,1].plot(X1_norm_pred*scale_X1)
    ax[1,1].plot(X2_norm_pred*scale_X2)
    # ax[0,1].set_ylim([-30, 0])
    # ax[1,1].set_ylim([-1100, 5500])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
